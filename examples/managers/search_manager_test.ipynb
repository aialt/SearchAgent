# %% [markdown]
# # Orchestrator Test - SearchWorkerPool MCP
#
# Validate that the `Orchestrator` (SearchManager role) connects to `search_worker_pool` and executes search subtasks in parallel.
#
# **Prerequisites**
# - `OPENAI_API_KEY` (and Firecrawl key if required) present in `.env`
# - Node 18+ with `npx firecrawl-mcp` reachable for the SearchAgent workers
# - Python environment has `langchain`, `langchain-openai` packages installed
#
# **What This Tests**
# - Orchestrator initialization with `search_worker_pool` MCP
# - `execute_subtasks` tool usage (provided by MCP pool)
# - Parallel execution across SearchAgent workers
# - Result aggregation

# %%
import os
import sys
from pathlib import Path

# get the current directory
cwd = os.getcwd()
print(f"Current working directory: {cwd}")

# REPO_ROOT = Path('/Users/leekayiu/Documents/workspace/manus_test/a2a_tree_backend')
REPO_ROOT = Path(cwd+'/../..')
if not REPO_ROOT.exists():
    raise FileNotFoundError(f'Repository path not found: {REPO_ROOT}')

SRC_PATH = REPO_ROOT / 'src'
if not SRC_PATH.exists():
    raise FileNotFoundError(f'Source path not found: {SRC_PATH}')

if str(SRC_PATH) not in sys.path:
    sys.path.insert(0, str(SRC_PATH))

env_path = REPO_ROOT / '.env'
if env_path.exists():
    try:
        from dotenv import load_dotenv
    except ImportError:
        load_dotenv = None

    if load_dotenv:
        load_dotenv(env_path)
    else:
        for line in env_path.read_text().splitlines():
            line = line.strip()
            if not line or line.startswith('#'):
                continue
            key, _, value = line.partition('=')
            if key and value:
                os.environ.setdefault(key, value.strip().strip('"'))
else:
    print(f'.env not found at {env_path}')

if 'OPENAI_API_KEY' not in os.environ:
    raise RuntimeError('OPENAI_API_KEY must be set before running the agent.')
# Out:
# Current working directory: /Users/steven/search agent/search_agent_framework/examples/managers

# %%
import os
from langchain_openai import ChatOpenAI
from search_agent.orchestration import Orchestrator
import asyncio

MODEL_NAME = 'gpt-5.1'
TEST_SUBTASKS = (
"""Could you provide a detailed list of Michelin three-star restaurants in the whole world? I especially want to know the name, main cuisine style and exact address of each restaurant.

Please organize the results in one Markdown table with the following columns:
Restaurant, Main Cuisine Style, Address
Don't ask me any questions, just output the results according to the column without omitting cells arbitrarily. The output format is ```markdown
{data_content}
```"""
)

TEST_SUBTASKS = (
"""Could you provide all of Trump's public speeches after being president in 2025, including title, time, location, and key points. Don't ask me any questions, just provide the results."
"""
)

TEST_SUBTASKS = (
"""	
Please sort out all African countries involved in the "Belt and Road" initiative and their capitals as of June 2025, and query the surface area (in sq.km, using 2022 statistics, rounded to an integer), population density (people/sq.km of land area, using 2022 statistics, rounded to an integer), total population (in thousand, using 2023 statistics, rounded to an integer), and the proportion of merchandise trade in GDP (in percentage of GDP, using 2023 statistics, rounded to one decimal place) of these countries according to the statistics of the World Bank.

Please output the sorted data in the format of one Markdown table. The column names in the table are: Country, Capital City, Surface Area (km²), Population Density (people/km² of land area), Total Population (thousands), Merchandise Trade (% of GDP).
Don't ask me any questions, just output the results according to the columns without omitting cells arbitrarily. The output format is ```markdown
{data_content}
```
"""
)

TEST_SUBTASKS = (
"""I'd like to know the information about all Ford vehicles first launched and revived from January 1, 2010 to December 31, 2024 in the US (not including model updates or facelifts). Information is needed as follows: Model Name (Year), Price, Dimensions (L/W/H, mm), Wheelbase (mm), Maximum Torque (N·m), Front Suspension Type, Rear Suspension Type, Advanced Driving Assistance System (Please list all ADAS equipped in this model), Intelligent Parking Assist (Please list all IPA equipped in this model). All information is for the standard edition, and if it doesn't have ADAS or IPA, fill in '-'.

Please organize the results in one Markdown table with the following columns: Model Name, Price (USD, launch MSRPs), Dimensions L/W/H (mm), Wheelbase (mm), Max Torque (N·m), Front Suspension, Rear Suspension, Advanced-Driver-Assist Systems (ADAS²), Intelligent Parking Assist
Dimensions should adopt the data that exclude mirror and the launch MSRPs usually refers to price without destination fee.

Don't ask me any questions, just output the results according to the columns without omitting cells arbitrarily. The output format is ```markdown
{data_content}
```.
"""
)
# Create a query from TEST_SUBTASKS
# TARGET_QUERY = f"Please answer the following {len(TEST_SUBTASKS)} questions in parallel:\n"
# for i, subtask in enumerate(TEST_SUBTASKS, 1):
#     TARGET_QUERY += f"{i}. {subtask}\n"


# Create model
orchestrator_model = ChatOpenAI(
    model=MODEL_NAME,
    api_key=os.getenv('OPENAI_API_KEY'),
    base_url=os.getenv('OPENAI_BASE_URL')
)

# Create Orchestrator (connects to search_worker_pool)
orchestrator = Orchestrator(
    name="orchestrator",
    model=orchestrator_model,
    enable_sequential_thinking=True,
)
# Initialize Orchestrator (will connect to search_worker_pool)
await orchestrator.start()

print('Orchestrator initialized with search_worker_pool.')
# Out:
# Warning: /Users/steven/search agent/search_agent_framework/models-config.json not found, using fallback configuration
# Orchestrator initialized with search_worker_pool.

# %%
# Test 2: Streaming execution with stream()
print('='*60)
print('STREAMING UPDATES:')
print('='*60)
async for chunk in orchestrator.stream(TEST_SUBTASKS):
    print(chunk)
    print('-'*60)
# Out:
# ============================================================
# STREAMING UPDATES:
# ============================================================
# {'model': {'messages': [AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 694, 'prompt_tokens': 2491, 'total_tokens': 3185, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.1-2025-11-13', 'system_fingerprint': None, 'id': 'chatcmpl-D3hmWOUlR3PNYMRG0BQdEISQv6R0E', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--1e98d0b5-8a08-4f89-b0d1-cba49640d5b7-0', tool_calls=[{'name': 'execute_subtasks', 'args': {'subtasks': ['List all Ford brand vehicle nameplates that were first launched in the U.S. market or revived (a nameplate returning after being discontinued) between January 1, 2010 and December 31, 2024, excluding simple model-year updates or facelifts. Provide model names and first U.S. model year of launch or revival.', 'For each Ford vehicle nameplate launched or revived in the U.S. between 2010 and 2024 (such as Ford C-Max Hybrid, C-Max Energi, Focus Electric, Fiesta ST, Fusion Hybrid, Fusion Energi, Taurus SHO 2010+, Flex EcoBoost, Transit Connect Wagon, Transit full-size van, F-150 Raptor, Edge ST, Explorer ST, Bronco 2021+, Bronco Sport, Maverick, Mustang Mach-E, F-150 Lightning, Transit Connect Electric, Escape PHEV, etc.), identify which are genuinely new nameplates or revivals versus trims of existing models, and produce a cleaned list of unique new or revived nameplates only.', 'For each confirmed new or revived U.S. Ford nameplate from 2010–2024 (e.g., Ford C-Max Hybrid 2013, C-Max Energi 2013, Focus Electric 2012, Transit full-size van 2015 U.S. introduction, Bronco 2021 revival, Bronco Sport 2021, Maverick 2022, Mustang Mach-E 2021, F-150 Lightning 2022, Transit Connect Wagon 2010 U.S., Transit Connect Electric 2011, Escape Plug-In Hybrid 2020/2021 U.S., Explorer Hybrid 2020, etc.), find the standard trim’s launch MSRP in USD at introduction in the U.S. excluding destination, and provide sources.', 'For each confirmed new or revived U.S. Ford nameplate from 2010–2024, find the standard trim’s overall dimensions (length, width without mirrors, height) in millimeters and wheelbase in millimeters at launch in the U.S. market, and provide sources.', 'For each confirmed new or revived U.S. Ford nameplate from 2010–2024, find the standard engine/motor system’s maximum torque in N·m at launch in the U.S. market, and provide sources.', 'For each confirmed new or revived U.S. Ford nameplate from 2010–2024, find the front suspension type and rear suspension type for the standard trim at launch in the U.S. market, and provide sources.', 'For each confirmed new or revived U.S. Ford nameplate from 2010–2024, identify all factory Advanced Driver Assistance Systems (ADAS) available on the standard trim at launch in the U.S. (e.g., forward collision warning, AEB, lane-keeping assist, adaptive cruise control, blind-spot monitoring, rear cross-traffic alert, driver-attention monitoring, traffic sign recognition, etc.), and provide sources.', "For each confirmed new or revived U.S. Ford nameplate from 2010–2024, identify all Intelligent Parking Assist / automated parking features available on the standard trim at launch in the U.S. (e.g., Active Park Assist, Enhanced Active Park Assist, etc.), and provide sources. If none, state '-'."]}, 'id': 'call_6jSfMRu1wUuJSaDDeQKLbxbI', 'type': 'tool_call'}], usage_metadata={'input_tokens': 2491, 'output_tokens': 694, 'total_tokens': 3185, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# ------------------------------------------------------------
# {'tools': {'messages': [ToolMessage(content='{"results":[{"subtask_index":0,"subtask":"List all Ford brand vehicle nameplates that were first launched in the U.S. market or revived (a nameplate returning after being discontinued) between January 1, 2010 and December 31, 2024, excluding simple model-year updates or facelifts. Provide model names and first U.S. model year of launch or revival.","result":"Here is a comprehensive list of Ford-brand vehicle nameplates that were either newly launched into the U.S. market or explicitly revived (a name returning after prior discontinuation) with their first U.S. model year between Jan 1, 2010 and Dec 31, 2024. I excluded mere model-year updates, mid‑cycle facelifts or new trim/variant introductions of an existing ongoing nameplate.\\n\\n- Ford Transit Connect — 2010 (first U.S. model year; commercially introduced to North America as a new-for‑market compact van)  \\n  Source: news/reviews covering the 2010 Transit Connect U.S. debut (e.g., MotorTrend, TruckingInfo).\\n\\n- Ford Fiesta — 2011 (first U.S. model year for the modern global Fiesta subcompact — returned/introduced to the U.S. as a distinct small-car product for MY2011)  \\n  Source: contemporary press and model coverage for the 2011 Ford Fiesta U.S. launch.\\n\\n- Ford C‑MAX (C‑Max Hybrid / C‑Max Energi) — 2013 (first U.S. model year for C‑MAX hybrid/plug‑in-hybrid compact MPV sold in U.S. market)  \\n  Source: Ford press and automotive reviews introducing the 2013 C‑MAX Hybrid and Energi.\\n\\n- Ford Transit (full-size Transit van) — 2015 (first U.S. model year for the global Transit family replacing the E-Series/introducing the modern Transit to North America)  \\n  Source: Ford media and coverage for the 2015 Transit U.S. launch.\\n\\n- Ford EcoSport — 2018 (first U.S. model year; small/subcompact crossover introduced to the North American market in late‑2017 as a 2018 model)  \\n  Source: Ford announcements and reviews for the 2018 EcoSport U.S. introduction.\\n\\n- Ford Ranger — 2019 (revival; nameplate returned to the U.S. market as a new midsize pickup for the 2019 model year after an earlier U.S. withdrawal)  \\n  Source: coverage and Ford statements on the Ranger\'s return to North America for MY2019.\\n\\n- Ford Mustang Mach‑E — 2021 (first U.S. model year; Mustang name used on an all‑electric crossover — a new nameplate application/major launch in the U.S. for MY2021)  \\n  Source: Ford press and widely covered U.S. introduction of the Mustang Mach‑E (2021 model year).\\n\\n- Ford Bronco (new-generation Bronco) — 2021 (revival; Bronco nameplate returned to the U.S. as an all‑new off‑road SUV family for the 2021 model year after decades off the U.S. market)  \\n  Source: Ford Bronco official materials and extensive press coverage of the 2021 Bronco revival.\\n\\n- Ford Bronco Sport — 2021 (first U.S. model year for the Bronco Sport nameplate; part of the revived Bronco family introduced for 2021 — new nameplate/application in U.S.)  \\n  Source: Ford Bronco family materials and reviews of the 2021 Bronco Sport launch.\\n\\n- Ford Maverick — 2022 (first U.S. model year; a new compact unibody pickup nameplate launched in the U.S. for MY2022)  \\n  Source: Ford press and auto media for the 2022 Maverick introduction.\\n\\nNotes and scope clarifications\\n- I treated a “revival” as a nameplate that had been discontinued from the U.S. market and then reintroduced as a distinct model line (examples: Ranger, Bronco). I treated a “launch” as the first time that nameplate was sold in the U.S. (examples: Transit Connect, EcoSport, Maverick, C‑MAX, Fiesta as the modern global version).\\n- I excluded cases that are only new powertrain variants, trim lines, or sub‑model name usage where the parent nameplate continued uninterrupted (for example: F‑150 Lightning is an important new electric F‑150 variant but not a new or revived Ford nameplate).\\n- I excluded model-year refreshes, facelifts, or generational updates to nameplat ...
# ------------------------------------------------------------
# {'model': {'messages': [AIMessage(content='```markdown\n| Model Name (Year, US launch MY) | Price (USD, launch MSRPs) | Dimensions L/W/H (mm) | Wheelbase (mm) | Max Torque (N·m) | Front Suspension | Rear Suspension | Advanced-Driver-Assist Systems (ADAS²) | Intelligent Parking Assist |\n|---------------------------------|---------------------------|------------------------|----------------|------------------|------------------|-----------------|----------------------------------------|----------------------------|\n| Transit Connect (2010)         | -                         | -                      | -              | -                | -                | -               | -                                      | -                          |\n| Fiesta (2011)                  | -                         | -                      | -              | -                | -                | -               | -                                      | -                          |\n| C-Max (2013)                   | -                         | -                      | -              | -                | -                | -               | -                                      | -                          |\n| Transit (full-size, 2015)      | -                         | -                      | -              | -                | -                | -               | -                                      | -                          |\n| EcoSport (2018)                | -                         | -                      | -              | -                | -                | -               | -                                      | -                          |\n| Ranger (2019, revival)         | -                         | -                      | -              | -                | -                | -               | -                                      | -                          |\n| Mustang Mach‑E (2021)          | -                         | -                      | -              | -                | -                | -               | -                                      | -                          |\n| Bronco (2021, revival)         | -                         | -                      | -              | -                | -                | -               | -                                      | -                          |\n| Bronco Sport (2021)            | -                         | -                      | -              | -                | -                | -               | -                                      | -                          |\n| Maverick (2022)                | -                         | -                      | -              | -                | -                | -               | -                                      | -                          |\n| F‑150 Lightning (2022, revival of Lightning name) | -      | -                      | -              | -                | -                | -               | -                                      | -                          |\n```', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 479, 'prompt_tokens': 8612, 'total_tokens': 9091, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 2432}}, 'model_provider': 'openai', 'model_name': 'gpt-5.1-2025-11-13', 'system_fingerprint': None, 'id': 'chatcmpl-D3hoK0y9Ckc4w1duDINDLVdvWoN3V', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--4d3202fe-ca7e-4b19-a00d-d363530bec51-0', usage_metadata={'input_tokens': 8612, 'output_tokens': 479, 'total_tokens': 9091, 'input_token_details': {'audio': 0, 'cache_read': 2432}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# ------------------------------------------------------------

# %%
# Cell 5: Cleanup
print("\nCleaning up...")
await orchestrator.close()
print('✓ Orchestrator and search_worker_pool closed.')
# Out:
# Cleaning up...
# ✓ Orchestrator and search_worker_pool closed.
